# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_once = pd.read_csv("once_asymptotic.csv", sep = ' ')
data_double = pd.read_csv("double_asymptotic.csv", sep = ' ')
data_linear = pd.read_csv("linear_asymptotic.csv", sep = ' ')

# %%
plt.scatter(data_once['size'], data_once['time'], s = 5)

# %%
plt.scatter(data_once['size'], np.sqrt(data_once['time']), s = 5)

# %%
plt.scatter(data_linear['size'], data_linear['time'], s = 5)

# %%
plt.scatter(data_linear['size'], np.sqrt(data_linear['time']), s = 5)

# %%
plt.scatter(data_double['size'], data_double['time'], s = 5)

# %%
plt.scatter(data_once['size'], data_once['time'], s = 5)
plt.scatter(data_linear['size'], data_linear['time'], s = 5)
plt.scatter(data_double['size'], data_double['time'], s = 5)
