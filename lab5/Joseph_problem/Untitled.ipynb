# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_array = pd.read_csv('array_asymptotic.csv', sep = ' ')
data_buffer = pd.read_csv('buffer_asymptotic.csv', sep = ' ')

# %%
plt.scatter(data_array['size'], data_array['time'], s = 5)
plt.scatter(data_buffer['size'], data_buffer['time'], s = 5)

# %%
plt.scatter(data_array['size'], data_array['time'], s = 5)

# %%
plt.scatter(data_buffer['size'], data_buffer['time'], s = 5)
