# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('data.csv') as file:
    data = pd.read_csv(file, delimiter=' ')

data
# Out:
#     size  time
# 0      1     4
# 1      2     5
# 2      3     8
# 3      4    10
# 4      5     7
# ..   ...   ...
# 94    95   521
# 95    96   535
# 96    97   551
# 97    98   520
# 98    99   572
#
# [99 rows x 2 columns]

# %%
size = data['size']
time = data['time']

plt.plot(size, time)
